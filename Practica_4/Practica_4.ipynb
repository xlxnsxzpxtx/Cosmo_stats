# %%
import numpy as np
import matplotlib.image as img
from PIL import Image
import numpy.fft as fft
import scipy.stats as stats
import matplotlib.pyplot as plt

# %% [markdown]
# <img src= 'practica_4.jpg' width="600px">

# %%
# 1) Power spectra, 5 random realizations 
# Create a 1D real space array in order to define your real space framework : between 0 and 10 with 10000
#values
n = 10000
rs_array = np.linspace(0,10,n)
d = 10/n

# Calculate the corresponding frequencies
#sampling_rate = 1 / (rs_array[1] - rs_array[0]) 
k = np.fft.fftfreq(rs_array.shape[0],d)

for i in range(10):
    print(f"Frequency: {k[i]:.2f} Hz, Binning Information: {1/k[i]:.2f} units")
# Out:
# Frequency: 0.00 Hz, Binning Information: inf units
# Frequency: 0.10 Hz, Binning Information: 10.00 units
# Frequency: 0.20 Hz, Binning Information: 5.00 units
# Frequency: 0.30 Hz, Binning Information: 3.33 units
# Frequency: 0.40 Hz, Binning Information: 2.50 units
# Frequency: 0.50 Hz, Binning Information: 2.00 units
# Frequency: 0.60 Hz, Binning Information: 1.67 units
# Frequency: 0.70 Hz, Binning Information: 1.43 units
# Frequency: 0.80 Hz, Binning Information: 1.25 units
# Frequency: 0.90 Hz, Binning Information: 1.11 units
# /tmp/ipykernel_9898/2975797933.py:13: RuntimeWarning: divide by zero encountered in scalar divide
#   print(f"Frequency: {k[i]:.2f} Hz, Binning Information: {1/k[i]:.2f} units")

# %%
k_norm = np.sqrt(k**2)

e = 0.1

def P_k(k_x, epsilon):
    return (np.sqrt(k_x**2) + epsilon)**(-2)


power_spectrum = P_k(k,e)

plt.loglog(k_norm,power_spectrum)
plt.xlabel('$|k|$')
plt.ylabel('P(k)')
# Out:
# Text(0, 0.5, 'P(k)')

# %%
# we define the array for alpha and the phase in the following way:
alpha_1 = np.random.normal(0, np.sqrt(P_k(k, e)), n)
alpha_2 = np.random.normal(0, np.sqrt(P_k(k, e)), n)
alpha_3 = np.random.normal(0, np.sqrt(P_k(k, e)), n)
alpha_4 = np.random.normal(0, np.sqrt(P_k(k, e)), n)
alpha_5 = np.random.normal(0, np.sqrt(P_k(k, e)), n)

phi_1 = np.random.uniform(0, 2 * np.pi, n)
phi_2 = np.random.uniform(0, 2 * np.pi, n)
phi_3 = np.random.uniform(0, 2 * np.pi, n)
phi_4 = np.random.uniform(0, 2 * np.pi, n)
phi_5 = np.random.uniform(0, 2 * np.pi, n)

# now, using the simmetry and antisymetry conditions for alpha and phi 
for i in range(n):
    alpha_1[-i] = alpha_1[i]
    alpha_2[-i] = alpha_2[i]
    alpha_3[-i] = alpha_3[i]
    alpha_4[-i] = alpha_4[i]
    alpha_5[-i] = alpha_5[i]

    phi_1[-i] = -phi_1[i]
    phi_2[-i] = -phi_2[i]
    phi_3[-i] = -phi_3[i]
    phi_4[-i] = -phi_4[i]
    phi_5[-i] = -phi_5[i]

# Compute ð
ð_1 = alpha_1 * np.exp(1j * phi_1)
ð_2 = alpha_2 * np.exp(1j * phi_2)
ð_3 = alpha_3 * np.exp(1j * phi_3)
ð_4 = alpha_4 * np.exp(1j * phi_4)
ð_5 = alpha_5 * np.exp(1j * phi_5)

for i in range(n): 
    ð_1[-i] = np.conj(ð_1[i])  
    ð_2[-i] = np.conj(ð_2[i]) 
    ð_3[-i] = np.conj(ð_3[i]) 
    ð_4[-i] = np.conj(ð_4[i])
    ð_5[-i] = np.conj(ð_5[i])

# %%
plot1 = fft.ifftn(fft.ifftshift(ð_1))
plot2 = fft.ifftn(fft.ifftshift(ð_2))
plot3 = fft.ifftn(fft.ifftshift(ð_3))
plot4 = fft.ifftn(fft.ifftshift(ð_4))
plot5 = fft.ifftn(fft.ifftshift(ð_5))

# %%
plt.plot(np.log(abs(plot4)),color='darkred',linestyle='-',label='$\delta_4$')
plt.plot(np.log(abs(plot5)),color='darkblue',linestyle='-',label='$\delta_5$')
plt.plot(np.log(abs(plot2)),color='darkgreen',linestyle='-',label='$\delta_2$')
plt.plot(np.log(abs(plot3)),color='violet',linestyle='-',label='$\delta_3$')
plt.plot(np.log(abs(plot1)),color='cyan',linestyle='-',label='$\delta_1$')
plt.xlabel('k')
plt.ylabel('$P(k)$')
plt.legend()
plt.grid()

# %% [markdown]
# ### Part 2: 3 power sprectrum, 1D realization

# %%
 #1) Power spectra, 5 random realizations 
# Create a 1D real space array in order to define your real space framework : between 0 and 10 with 1000
n_1 = 1000
rs_array_1 = np.linspace(0,10,n_1)
d_1 = 10/n_1

k1 = np.fft.fftfreq(rs_array_1.shape[0],d_1)
k2 = np.fft.fftfreq(rs_array_1.shape[0],d_1)
k3 = np.fft.fftfreq(rs_array_1.shape[0],d_1)

for i in range(10):
    print(f"Frequency: {k1[i]:.2f} Hz, Binning Information: {1/k1[i]:.2f} units")
# Out:
# Frequency: 0.00 Hz, Binning Information: inf units
# Frequency: 0.10 Hz, Binning Information: 10.00 units
# Frequency: 0.20 Hz, Binning Information: 5.00 units
# Frequency: 0.30 Hz, Binning Information: 3.33 units
# Frequency: 0.40 Hz, Binning Information: 2.50 units
# Frequency: 0.50 Hz, Binning Information: 2.00 units
# Frequency: 0.60 Hz, Binning Information: 1.67 units
# Frequency: 0.70 Hz, Binning Information: 1.43 units
# Frequency: 0.80 Hz, Binning Information: 1.25 units
# Frequency: 0.90 Hz, Binning Information: 1.11 units
# /tmp/ipykernel_9898/1606975166.py:12: RuntimeWarning: divide by zero encountered in scalar divide
#   print(f"Frequency: {k1[i]:.2f} Hz, Binning Information: {1/k1[i]:.2f} units")

# %%
# 3) three diferents power spectrum 
k_norm_1 = np.sqrt(k1**2)
e1 = 0.001

def P_k2(k_2, epsilon2):
    return (np.sqrt(k_2**2) + epsilon2)**(-2)


def P_k3(k_3,epsilon3):
    return(np.sqrt(k_3**2) + epsilon3)**(-3)

def P_k4(k_4,epsilon4):
    return(np.sqrt(k_4**2) + epsilon4)**(-4) 


power_spectrum2 = P_k2(k1,e1)
power_spectrum3 = P_k3(k2,e1) 
power_spectrum4 = P_k4(k3,e1)

# %%
# for P_2(k)
alpha_22 = np.random.normal(0,np.sqrt(power_spectrum2), n_1)
phi_22 = np.random.uniform(0, 2*np.pi, n_1)
# for P_3(k)
alpha_33 = np.random.normal(0,np.sqrt(power_spectrum3), n_1)
phi_33 = np.random.uniform(0, 2*np.pi, n_1)
# for the P_4(k)
alpha_44 = np.random.normal(0,np.sqrt(power_spectrum4), n_1)
phi_44 = np.random.uniform(0, 2*np.pi, n_1)


for i in range(500):
    alpha_22[-i] = alpha_22[i]
    alpha_33[-i] = alpha_33[i]
    alpha_44[-i] = alpha_44[i]


    phi_22[-i] = - phi_22[i]
    phi_33[-i] = - phi_33[i]
    phi_44[-i] = - phi_44[i]


ð_22 = alpha_22*np.exp(1j*phi_22)
ð_33 = alpha_33*np.exp(1j*phi_33)
ð_44 = alpha_44 * np.exp(1j*phi_44)

for i in range(500): 
    ð_22[-i] = np.conj(ð_22[i])  
    ð_33[-i] = np.conj(ð_33[i]) 
    ð_44[-i] = np.conj(ð_44[i])

# %%
plot22 = fft.ifftn(fft.ifftshift(ð_22))
plot33 = fft.ifftn(fft.ifftshift(ð_33))
plot44 = fft.ifftn(fft.ifftshift(ð_44))

# %%
plt.plot(np.log(abs(plot22)),color='darkred',linestyle='-')
plt.title('$\delta_2$')
plt.xlabel('k')
plt.ylabel('P(k)')
plt.axis()
# Out:
# (-49.95, 1048.95, -0.6320235905341026, -0.5501856758312992)

# %%
plt.plot(np.log(abs(plot33)),color='darkred',linestyle='-')
plt.title('$\delta_3$')
plt.xlabel('k')
plt.ylabel('P(k)')
plt.axis()
# Out:
# (-49.95, 1048.95, 3.3326578019004014, 3.3358526565258684)

# %%
plt.plot(np.log(abs(plot44)),color='darkred',linestyle='-')
plt.title('$\delta_4$')
plt.xlabel('k')
plt.ylabel('P(k)')
plt.axis()
# Out:
# (-49.95, 1048.95, 5.305492871074566, 5.306199957974037)

# %% [markdown]
# ### Part 3: Generate a Gaussian Random Field in 2D

# %%
rs_2d_array  = np.random.uniform(0,10,(100,100))
k_11 = fft.fftfreq(rs_2d_array.shape[0],d_1)
k_22 = fft.fftfreq(rs_2d_array.shape[1],d_1)

# centiring the frequencies
k_11 = fft.fftshift(k_11)
k_11 = fft.fftshift(k_11)


# the norm of the frequencies
k_norm = np.zeros((100,100)) 
for i in range(100):
    for j in range(100):
        k_norm[i,j] = np.sqrt(k_11[i]**2 + k_22[j]**2)

# %%
def P_kk(k_2d,epsilon2d):
    return (np.abs(k_2d) + epsilon2d)**(-2)


power_spectrum_2d = P_kk(k_norm,e)

# %%
# we define the array for alpha and the phase in the following way:
alpha_1_2d = np.random.normal(0, power_spectrum_2d, (100,100))
alpha_2_2d = np.random.normal(0, power_spectrum_2d, (100,100))
alpha_3_2d = np.random.normal(0, power_spectrum_2d, (100,100))
alpha_4_2d = np.random.normal(0, power_spectrum_2d, (100,100))
alpha_5_2d = np.random.normal(0, power_spectrum_2d, (100,100))


phi_1_2d= np.random.uniform(0, 2 * np.pi, (100,100))
phi_2_2d= np.random.uniform(0, 2 * np.pi, (100,100))
phi_3_2d= np.random.uniform(0, 2 * np.pi, (100,100))
phi_4_2d= np.random.uniform(0, 2 * np.pi, (100,100))
phi_5_2d= np.random.uniform(0, 2 * np.pi, (100,100))


# now, using the simmetry and antisymetry conditions for alpha and phi 
for i in range(100):
    for j in range(100):
        alpha_1_2d[-i,-j] = alpha_1_2d[i,j]
        alpha_2_2d[-i,-j] = alpha_2_2d[i,j]
        alpha_3_2d[-i,-j] = alpha_3_2d[i,j]
        alpha_4_2d[-i,-j] = alpha_4_2d[i,j]
        alpha_5_2d[-i,-j] = alpha_5_2d[i,j]       

        phi_1_2d[-i,-j] = -phi_1_2d[i,j]
        phi_2_2d[-i,-j] = -phi_1_2d[i,j]
        phi_3_2d[-i,-j] = -phi_1_2d[i,j]
        phi_4_2d[-i,-j] = -phi_1_2d[i,j]

# %%
delta_k1 = np.zeros((100,100), dtype=complex)
delta_k2 = np.zeros((100,100), dtype=complex)
delta_k3 = np.zeros((100,100), dtype=complex)
delta_k4 = np.zeros((100,100), dtype=complex)
delta_k5 = np.zeros((100,100), dtype=complex)

for i in range(100):
    for j in range(100):
        delta_k1[i,j] = alpha_1_2d[i,j]*np.exp(1j*phi_1_2d[i,j])
        delta_k2[i,j] = alpha_2_2d[i,j]*np.exp(1j*phi_2_2d[i,j])
        delta_k3[i,j] = alpha_3_2d[i,j]*np.exp(1j*phi_3_2d[i,j])
        delta_k4[i,j] = alpha_4_2d[i,j]*np.exp(1j*phi_4_2d[i,j])
        delta_k5[i,j] = alpha_5_2d[i,j]*np.exp(1j*phi_5_2d[i,j])
for i in range(50):
    for j in range(50):
        delta_k1[-i][-j] = np.conj(delta_k1[i][j])
        delta_k2[-i][-j] = np.conj(delta_k2[i][j])
        delta_k3[-i][-j] = np.conj(delta_k3[i][j])
        delta_k4[-i][-j] = np.conj(delta_k4[i][j])
        delta_k5[-i][-j] = np.conj(delta_k5[i][j])

delta_k1[50][50] = np.real(delta_k1[50][50]) 
delta_k2[50][50] = np.real(delta_k2[50][50])
delta_k3[50][50] = np.real(delta_k3[50][50])
delta_k4[50][50] = np.real(delta_k4[50][50])
delta_k5[50][50] = np.real(delta_k5[50][50])

# %%
# the inverse transfor for the 5 realizations are
plt_2d_1 = fft.ifftn(fft.ifftshift(delta_k1))
plt_2d_2 = fft.ifftn(fft.ifftshift(delta_k2)) 
plt_2d_3 = fft.ifftn(fft.ifftshift(delta_k3))
plt_2d_4 = fft.ifftn(fft.ifftshift(delta_k4))
plt_2d_5 = fft.ifftn(fft.ifftshift(delta_k5))

# %%
# the plot for the first realization is 
plt.imshow(np.log(abs(plt_2d_1)))

# %%
# the plot for the second realization is
plt.imshow(np.log(abs(plt_2d_2)))

# %%
# the plot for the third realization is
plt.imshow(np.log(abs(plt_2d_3)))

# %%
# the plot for the fourth realization is
plt.imshow(np.log(abs(plt_2d_4)))

# %%
# and finally, the plot for the fifth realization is
plt.imshow(np.log(abs(plt_2d_5)))
